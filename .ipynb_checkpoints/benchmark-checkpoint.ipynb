# %%
import quarters
import companies
import numpy as np
import pandas as pd
import numpy.linalg as la
import datetime
import yfinance as yf

start_year = 1995
end_year = 2019
a = np.array([0.023734,1.329796395805503/100])

# %%
def get_stock_weights(start_year, end_year, a):
    rfr = quarters.get_mean_rfr_between_years(start_year, end_year)
    gdp = quarters.get_gdp_growth_between_years(start_year, end_year)

    returns = pd.read_csv(f'./data/returns/returns_{start_year}-{end_year}.csv').set_index('Unnamed: 0')

    mu1 = returns.mean()
    mu2 = np.array([np.mean(rfr), np.mean(gdp)])
    #print(mu2)
    all_companies = returns.columns
    n_companies = returns.shape[1]

    #adding external parameters
    returns['avg_rfr'] = rfr
    returns['gdp_growth'] = gdp

    total_points = returns.shape[1]
    
    returns_array = returns.to_numpy().T.astype(float)
    cov_array = np.cov(returns_array)
    #print(cov_array)
    sigma11 = cov_array[0:n_companies, 0:n_companies]
    sigma21 = cov_array[n_companies:total_points, 0:n_companies]
    sigma12 = cov_array[0:n_companies, n_companies:total_points]
    sigma22 = cov_array[n_companies:total_points, n_companies:total_points]
    #print(sigma12, sigma22)
    mu = mu1 + sigma12@la.inv(sigma22)@(a-mu2)
    sigma = sigma11 - sigma12@la.inv(sigma22)@sigma21
    w_prime_cond = la.inv(sigma)@mu/(np.ones(n_companies)@la.inv(sigma)@mu)
    w_prime = la.inv(sigma11)@mu1/(np.ones(n_companies)@la.inv(sigma11)@mu1)
    return w_prime_cond, w_prime

# %%
from compare import compare_to_benchmark

# %%
all_companies = pd.read_csv(f'./data/returns/returns_{start_year}-{end_year}.csv').set_index('Unnamed: 0').columns
print(all_companies)

w1=[4.948164430305507e-10, 1.7614318901641165e-10, 6.054779474920418e-11, 1.674731729151316e-10, 2.569755915855341e-10, 2.827317527962506e-10, 9.616344280281695e-11, 2.0975142017860457e-10, 5.7832938533018616e-11, 0.06424928354896987, 0.0776564712102905, 1.007349828822585e-10, 8.27234662419562e-11, 1.410265715153801e-10, 0.060337218917329224, 6.584838605758495e-10, 1.4099305466209813e-09, 8.835088840744245e-11, 6.654537647976172e-11, 7.45045826825152e-10, 8.617408924441119e-11, 2.1198561964766794e-10, 6.287875930867192e-10, 2.1103545376629222e-10, 5.35557685681256e-09, 1.9381310413578388e-10, 0.021603647481915227, 1.1017377376943919e-10, 3.369257750996578e-10, 4.5092855297839094e-11, 9.890873615465715e-11, 1.239279814191e-10, 8.17876777209958e-11, 9.479466931851645e-07, 1.6123667417226965e-10, 0.05279275863055685, 6.419636728092929e-10, 4.5579312293828696e-10, 1.6754295592690556e-10, 3.115919840001684e-10, 3.0228225285340565e-10, 1.8915272477236853e-10, 3.9565688092204253e-10, 1.3557369850474874e-10, 1.2724503616260303e-10, 1.5427081403547115e-10, 3.160649570670029e-07, 5.419302603402251e-10, 0.061082073817141584, 1.1365209425626975e-10, 1.5990439864430664e-09, 0.02868532426960694, 1.8976693990630016e-10, 1.8656158251492998e-10, 4.87318394574018e-11, 1.0838256108350161e-09, 6.1055744869548e-11, 3.8373454724845243e-10, 9.541610266551721e-11, 2.376917768994358e-10, 1.324985658885026e-08, 2.469509083938332e-10, 0.1505648019129846, 1.8390330018023353e-10, 1.414813940705103e-10, 8.032150169771836e-11, 1.1707231059718474e-10, 1.437369137874759e-09, 2.379231354644081e-10, 0.0011849361952237887, 1.9713876446725534e-10, 5.7299787871842845e-11, 3.926383447801879e-11, 2.4879101366812134e-10, 2.2163722452277884e-10, 3.4961713697069374e-10, 1.3997303825622446e-10, 2.457738567990632e-10, 3.6097233363777126e-10, 7.419898020544463e-10, 1.1212407353284104e-09, 1.5910672858455707e-10, 7.392863565808028e-10, 3.9775893996664633e-10, 5.832484529960382e-11, 1.0945847825720697e-10, 2.334075646829782e-10, 1.0992344632235027e-10, 6.46586260316562e-08, 0.017338836885694715, 2.2843553979136982e-10, 1.4022724667921105e-10, 3.7767666947699535e-10, 0.06783942425703335, 0.188263313207714, 0.03523747700819351, 1.6862574704417136e-10, 0.05582450465129036, 1.2029980725533022e-10, 0.05791009936285337, 1.1859018748570065e-09, 2.1444126758108567e-10, 7.035751660895268e-11, 1.7524857341445126e-10, 8.905842980809569e-11, 9.180761734797523e-10, 1.1557945726842773e-10, 9.374521305382879e-11, 2.7122919265920006e-08, 2.3110247797888886e-10, 1.388224381231746e-10, 1.6624592053649936e-10, 7.727383885988694e-09, 3.632924314892921e-10, 2.9013250801294707e-10, 1.5984588939353115e-10, 1.902888979622222e-10, 0.029761615672534214, 7.836683505535872e-11, 8.208927147000203e-11, 1.375652669841576e-10, 1.2048786973868133e-10, 5.01950683336383e-11, 0.029666762438158398, 2.4892168635455905e-08, 3.35703816859815e-09, 1.9611333484802927e-10, 1.4909605822540317e-10, 2.290200271858282e-10, 2.5589495453253075e-10, 7.139231564629211e-10, 9.468542872190775e-09, 2.3014316048292397e-10, 2.2610903586204142e-10]

#comparison1= compare_to_benchmark([w1], all_companies, datetime.datetime(2019, 1, 1))
# Out:
# Index(['MMM', 'ABT', 'ADM', 'ADP', 'APD', 'MO', 'AEP', 'AXP', 'AIG', 'AMGN',
#        ...
#        'UNP', 'UNH', 'VZ', 'VFC', 'WBA', 'WMT', 'WFC', 'WMB', 'GWW', 'XEL'],
#       dtype='object', length=134)

# %%
import json
q_dates = quarters.get_dates_between_years(2019, 2023)
weights1 = json.load(open('./basic_weights.json', 'r'))
weights2 = json.load(open('./weights_rfr_gdp.json', 'r'))
weights3 = json.load(open('./weights_rfr_gdp_unm_inf.json', 'r'))
weights4 = json.load(open('./weights_rfr_gdp_inf.json', 'r'))


df = pd.DataFrame(columns=['benchmark'])

for year in q_dates:
    for quarter in q_dates[year]:
        print(year, quarter)
        str_year = str(year)
        w1 = weights1[str_year][quarter]['weights']
        w2 = weights2[str_year][quarter]['weights']
        w3 = weights3[str_year][quarter]['weights']
        
        start_date = q_dates[year][quarter]['start']
        end_date = q_dates[year][quarter]['end']
        
        comparison = compare_to_benchmark([w1, w2, w3], all_companies, start_date)
        range = comparison.loc[(comparison.index>=start_date-datetime.timedelta(days=1)) & (comparison.index<=end_date+datetime.timedelta(days=1))]
        if df.empty:
            df = range
        else:
            last_row = df.iloc[-1]

            for column in last_row.index:
                value = last_row[column]
                range[column] *= value
            
            df = pd.concat([df, range])
        print(range)
# Out:
# 2019 Q1
#                            benchmark  portfolio_1  portfolio_2  portfolio_3
# Date
# 2019-01-02 00:00:00-05:00   1.000000     1.000000     1.000000     1.000000
# 2019-01-03 00:00:00-05:00   0.976137     0.984055     0.982593     0.985327
# 2019-01-04 00:00:00-05:00   1.008834     1.005228     1.003887     1.007254
# 2019-01-07 00:00:00-05:00   1.016788     1.008681     1.006862     1.011557
# 2019-01-08 00:00:00-05:00   1.026341     1.018921     1.016766     1.021549
# ...                              ...          ...          ...          ...
# 2019-03-26 00:00:00-04:00   1.128620     1.134066     1.137596     1.139128
# 2019-03-27 00:00:00-04:00   1.122719     1.130415     1.134177     1.134933
# 2019-03-28 00:00:00-04:00   1.126975     1.130688     1.132896     1.135762
# 2019-03-29 00:00:00-04:00   1.134081     1.136722     1.139626     1.141885
# 2019-04-01 00:00:00-04:00   1.147530     1.136718     1.141248     1.143050
#
# [62 rows x 4 columns]
# 2019 Q2
# /tmp/ipykernel_84136/1273442640.py:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                            benchmark  portfolio_1  portfolio_2  portfolio_3
# Date
# 2019-04-02 00:00:00-04:00   1.147530     1.136718     1.141248     1.143050
# 2019-04-03 00:00:00-04:00   1.149335     1.134622     1.139602     1.143388
# 2019-04-04 00:00:00-04:00   1.152385     1.136674     1.140564     1.145381
# 2019-04-05 00:00:00-04:00   1.157963     1.146259     1.147931     1.153612
# 2019-04-08 00:00:00-04:00   1.158846     1.147723     1.149502     1.155006
# ...                              ...          ...          ...          ...
# 2019-06-25 00:00:00-04:00   1.172426     1.205177     1.190552     1.186294
# 2019-06-26 00:00:00-04:00   1.171256     1.196217     1.181721     1.177822
# 2019-06-27 00:00:00-04:00   1.175410     1.198038     1.180927     1.180402
# 2019-06-28 00:00:00-04:00   1.181458     1.200256     1.185401     1.183413
# 2019-07-01 00:00:00-04:00   1.192184     1.201179     1.186712     1.184681
#
# [63 rows x 4 columns]
# 2019 Q3
# /tmp/ipykernel_84136/1273442640.py:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                            benchmark  portfolio_1  portfolio_2  portfolio_3
# Date
# 2019-07-02 00:00:00-04:00   1.192184     1.201179     1.186712     1.184681
# 2019-07-03 00:00:00-04:00   1.201716     1.212439     1.196163     1.195735
# 2019-07-05 00:00:00-04:00   1.200348     1.209170     1.192403     1.192376
# 2019-07-08 00:00:00-04:00   1.193753     1.206530     1.187740     1.189987
# 2019-07-09 00:00:00-04:00   1.195241     1.207387     1.188396     1.191000
# ...                              ...          ...          ...          ...
# 2019-09-25 00:00:00-04:00   1.202498     1.294734     1.247036     1.274544
# 2019-09-26 00:00:00-04:00   1.199992     1.301616     1.250867     1.281107
# 2019-09-27 00:00:00-04:00   1.193528     1.292996     1.240222     1.272735
# 2019-09-30 00:00:00-04:00   1.199063     1.299302     1.241643     1.278386
# 2019-10-01 00:00:00-04:00   1.184801     1.291632     1.234373     1.270777
#
# [64 rows x 4 columns]
# 2019 Q4
# /tmp/ipykernel_84136/1273442640.py:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
py:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                            benchmark  portfolio_1  portfolio_2  portfolio_3
# Date
# 2022-01-03 00:00:00-05:00   1.979874     2.308432     1.976177     1.952045
# 2022-01-04 00:00:00-05:00   1.979211     2.314051     1.988918     1.961021
# 2022-01-05 00:00:00-05:00   1.941206     2.300327     1.976524     1.949170
# 2022-01-06 00:00:00-05:00   1.939382     2.276340     1.966328     1.935472
# 2022-01-07 00:00:00-05:00   1.931715     2.281479     1.971313     1.939982
# ...                              ...          ...          ...          ...
# 2022-03-28 00:00:00-04:00   1.895393     2.468471     2.135218     2.106983
# 2022-03-29 00:00:00-04:00   1.918841     2.484183     2.156030     2.124416
# 2022-03-30 00:00:00-04:00   1.906993     2.498119     2.165436     2.136000
# 2022-03-31 00:00:00-04:00   1.877642     2.480194     2.148535     2.119629
# 2022-04-01 00:00:00-04:00   1.882963     2.509489     2.180903     2.151714
#
# [63 rows x 4 columns]
# 2022 Q2
# /tmp/ipykernel_84136/1273442640.py:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                            benchmark  portfolio_1  portfolio_2  portfolio_3
# Date
# 2022-04-04 00:00:00-04:00   1.882963     2.509489     2.180903     2.151714
# 2022-04-05 00:00:00-04:00   1.859179     2.499866     2.172057     2.146673
# 2022-04-06 00:00:00-04:00   1.840588     2.508355     2.184794     2.160344
# 2022-04-07 00:00:00-04:00   1.849863     2.525884     2.205494     2.183599
# 2022-04-08 00:00:00-04:00   1.844916     2.532201     2.222515     2.197704
# ...                              ...          ...          ...          ...
# 2022-06-27 00:00:00-04:00   1.608716     2.249520     2.033803     2.029733
# 2022-06-28 00:00:00-04:00   1.575845     2.221980     2.017846     2.011780
# 2022-06-29 00:00:00-04:00   1.574562     2.210956     2.014358     2.008996
# 2022-06-30 00:00:00-04:00   1.561770     2.203361     2.001279     1.998100
# 2022-07-01 00:00:00-04:00   1.578288     2.250227     2.037110     2.037491
#
# [62 rows x 4 columns]
# 2022 Q3
#                            benchmark  portfolio_1  portfolio_2  portfolio_3
# Date
# 2022-07-05 00:00:00-04:00   1.578288     2.250227     2.037110     2.037491
# 2022-07-06 00:00:00-04:00   1.583618     2.270601     2.049533     2.049907
# 2022-07-07 00:00:00-04:00   1.607336     2.289891     2.065524     2.063837
# 2022-07-08 00:00:00-04:00   1.606014     2.287328     2.050108     2.049222
# 2022-07-11 00:00:00-04:00   1.587667     2.279499     2.038902     2.038562
# ...                              ...          ...          ...          ...
# 2022-09-26 00:00:00-04:00   1.511540     2.172628     1.931090     1.931178
# 2022-09-27 00:00:00-04:00   1.507682     2.167828     1.916404     1.915861
# 2022-09-28 00:00:00-04:00   1.537347     2.215843     1.957427     1.960199
# 2022-09-29 00:00:00-04:00   1.505234     2.167252     1.924558     1.928574
# 2022-09-30 00:00:00-04:00   1.481957     2.137662     1.903199     1.905483
#
# [63 rows x 4 columns]
# 2022 Q4
# /tmp/ipykernel_84136/1273442640.py:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 14
#      12 print(year, quarter)
#      13 str_year = str(year)
# ---> 14 w1 = weights1[str_year][quarter]['weights']
#      15 w2 = weights2[str_year][quarter]['weights']
#      16 w3 = weights3[str_year][quarter]['weights']
#
# KeyError: 'Q4'

# %%
import plotly.express as px
#comparison['benchmark']  = comparison
px.line(df)
